# %% [markdown]
# LINEAR_REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# Scikit-learn is a powerful Python library used for machine learning.
# It provides simple and efficient tools for data analysis and modeling, including various algorithms for classification, regression, clustering, and more

# %%
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area (per sqr feet)')
plt.ylabel('Price (us$)')
plt.scatter(df.area,df.price,color='k',marker='+')

# %%
new_df=df.drop('price',axis=1)
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [raw]
# Create linear regression object

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
plt.xlabel('Area (per sqr feet)')
plt.ylabel('Price (us$)')
plt.scatter(df.area,df.price,color='k',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='green')

# %%
reg.predict([[3300]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [raw]
# Y = m * X + b
# m is coefficient and b is intercept

# %%
# m
reg.coef_
# Out:
# array([135.78767123])

# %%
# b
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %% [raw]
# Predict price of a home with area = 5000 sqr ft

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
m=reg.coef_
m
# Out:
# array([135.78767123])

# %%
b=reg.intercept_
b
# Out:
# 180616.43835616432

# %%
y=m*5000+b
y
# Out:
# array([859554.79452055])

# %%
859554.7945061643
# Out:
# 859554.7945061643

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df=pd.read_csv('areas.csv')
df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
reg.predict(df)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
p=reg.predict(df)

# %%
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df['price']=p

# %%
df.to_csv('prediction.csv',index=False)

# %%
a=pd.read_csv('prediction.csv')
a
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df=pd.read_csv('homeprices_multiples.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms.median()
# Out:
# 4.0

# %%
df.bedrooms.mode()
# Out:
# 0    3.0
# Name: bedrooms, dtype: float64

# %%
df.bedrooms.mean()
# Out:
# 4.2

# %%
df.bedrooms=df.bedrooms.fillna(df.bedrooms.mean())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.2   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg=linear_model.LinearRegression()
reg.fit(df.drop('price',axis=1),df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  116.66950551, 18756.28806982, -3675.75111708])

# %%
reg.intercept_
# Out:
# 231586.00639409182

# %% [raw]
# FIND PRICE OF HOME WITH 3000 SQR FT AREA, 3 BEDROOMS, 40 YEAR OLD

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([490833.34243748])

# %%
 116.66950551*3000+18756.28806982*3+-3675.75111708*40+231586.00639409182
# Out:
# 490833.3424503518

# %% [raw]
# FIND PRICE OF HOME WITH 2500 SQR FT AREA, 4 BEDROOMS, 5 YEAR OLD

# %%
 116.66950551*2500+18756.28806982*4+-3675.75111708*5+231586.00639409182
# Out:
# 579906.1668629718

# %%
pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5589 sha256=c1dc2af757902b8c7eb35e9d3a68c7859297b5992e4b58d01f9114250faf88d7
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\5b\79\fb\d25928e599c7e11fe4e00d32048cd74933f34a74c633d2aea6
# Successfully built word2number
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from word2number import w2n

# %%
d=pd.read_csv('hiring.csv')
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d.experience=d.experience.fillna('zero')
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d.experience=d.experience.apply(w2n.word_to_num)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
import math
median_test_score = math.floor(d['test_score(out of 10)'].mean())
median_test_score
# Out:
# 7

# %%
d['test_score(out of 10)'] = d['test_score(out of 10)'].fillna(median_test_score)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg = linear_model.LinearRegression()
reg.fit(d[['experience','test_score(out of 10)','interview_score(out of 10)']],d['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])

# %%
reg.predict([[12,10,10]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93747.79628651])

# %% [markdown]
# SAVE AND LOAD TRAINED MODEL

# %% [markdown]
# 5000 SQT FT --->PREDICTED MODEL ---> O/P

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model=linear_model.LinearRegression()
model.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
model.predict([[5000]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# SAVE MODEL TO A FILE USING PYTHON PICKLE

# %%
import joblib

# %%
import pickle
with open('model_pickle','wb') as file:
    pickle.dump(model,file)

# %%
with open('model_pickle','rb') as file:
    mp = pickle.load(file)

# %%
mp.coef_
# Out:
# array([135.78767123])

# %%
mp.intercept_
# Out:
# 180616.43835616432

# %%
mp.predict([[5000]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# SAVE TRAINED MODEL USING JOBLIB

# %%
joblib.dump(model, 'model_joblib')
# Out:
# ['model_joblib']

# %%
mj=joblib.load('model_joblib')

# %%
mj.coef_
# Out:
# array([135.78767123])

# %%
mj.intercept_
# Out:
# 180616.43835616432

# %%
mj.predict([[5000]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
